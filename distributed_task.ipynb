# %%
from mpi4py import MPI
comm = MPI.COMM_WORLD
rank = comm.Get_rank()
size = comm.Get_size()

if rank == 0:
    for i in range(1, size):
        data = comm.recv(source=i)
        print(f"Master received: {data}")
else:
    comm.send({"rank": rank, "result": rank * 10}, dest=0)
# Out:
# UsageError: Line magic function `%%writefile` not found.
